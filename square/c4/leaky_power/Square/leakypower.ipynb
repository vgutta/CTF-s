# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ptx = np.load('leaky_power/plaintexts.npy')
pwr = np.load('leaky_power/powertraces.npy')

# %%
print(ptx.shape)
pwr.shape
# Out:
# (75, 16)
# (75, 3000)

# %%
plt.figure(figsize=(15,5))
plt.plot(pwr[0])
plt.show()
